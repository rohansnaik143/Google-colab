# %% [markdown]
# <a href="https://colab.research.google.com/github/rohansnaik143/Google-colab/blob/main/labsheet8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

text_data="Python is a popular programming language"
wordcloud=WordCloud(width=800,height=400,background_color='black').generate(text_data)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud)
ply.title("word cloud")
plt.axis('off')
plt.show()

words=text_data.split()
word_counts=Counter(words)
plt.figure(figsize=(10,5))
plt.bar(word_counts.keys(),word_count.values())
plt.title('Histogram of word frequencies')
plt.xlabel('words')
plt.ylabel('frequency')
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-49bbf991d538> in <cell line: 10>()
#       8 plt.figure(figsize=(10,5))
#       9 plt.imshow(wordcloud)
# ---> 10 ply.title("word cloud")
#      11 plt.axis('off')
#      12 plt.show()
#
# NameError: name 'ply' is not defined

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

text_data="Python is a popular programming language"
wordcloud=WordCloud(width=800,height=400,background_color='black').generate(text_data)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud)
plt.title("word cloud")
plt.axis('off')
plt.show()


words=text_data.split()
word_counts=Counter(words)
plt.figure(figsize=(10,5))
plt.bar(word_counts.keys(),word_count.values())
plt.title('Histogram of word frequencies')
plt.xlabel('words')
plt.ylabel('frequency')
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a07441c4c477> in <cell line: 18>()
#      16 word_counts=Counter(words)
#      17 plt.figure(figsize=(10,5))
# ---> 18 plt.bar(word_counts.keys(),word_count.values())
#      19 plt.title('Histogram of word frequencies')
#      20 plt.xlabel('words')
#
# NameError: name 'word_count' is not defined
